# %%
import numpy as np 
import cv2
  
#fourcc = cv2.VideoWriter_fourcc("D", "I", "B", " ")
#out = cv2.VideoWriter('frame_mosic.MP4',fourcc, 20.0, (640,480))
  
cv2.namedWindow("CaptureFace")
#调用摄像头
cap=cv2.VideoCapture(0)
#人眼识别器分类器
classfier=cv2.CascadeClassifier("D:\Anaconda\envs\py36\Lib\site-packages\cv2\data\haarcascade_mcs_eyes.xml")
while cap.isOpened():
 read,frame=cap.read()
 if not read:
  break
 #灰度转换
 grey=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
 #人脸检测
 Rects = classfier.detectMultiScale(grey, scaleFactor = 1.2, minNeighbors = 3, minSize = (32, 32))
 if len(Rects) > 0:   
  for Rect in Rects: 
    x, y, w, h = Rect 
    # 打码：使用高斯噪声替换识别出来的人眼所对应的像素值
    frame[y+10:y+h-10,x:x+w,0]=np.random.normal(size=(h-20,w))
    frame[y+10:y+h-10,x:x+w,1]=np.random.normal(size=(h-20,w))
    frame[y+10:y+h-10,x:x+w,2]=np.random.normal(size=(h-20,w))
  
 cv2.imshow("CaptureFace",frame)
 if cv2.waitKey(5)&0xFF==ord('q'):
  break
 # 保存视频
 #out.write(frame)
#释放相关资源
cap.release()
#out.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-21-66c25bc791fa> in <module>
#      17  grey=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
#      18  #人脸检测
# ---> 19  Rects = classfier.detectMultiScale(grey, scaleFactor = 1.2, minNeighbors = 3, minSize = (32, 32))
#      20  if len(Rects) > 0:
#      21   for Rect in Rects:
#
# error: OpenCV(4.1.1) C:\projects\opencv-python\opencv\modules\objdetect\src\cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'cv::CascadeClassifier::detectMultiScale'

# %%
import os
import cv2
import time
import numpy as np

os.makedirs("E:/testttt/")
def endwith(s,*endstring):
    resultArray = map(s.endswith,endstring)
    if True in resultArray:
        return True
    else:
        return False

def readAllImg(path,*suffix):
    try:

        s = os.listdir(path)
        resultArray = []
        fileName = os.path.basename(path)
        resultArray.append(fileName)

        for i in s:
            if endwith(i, suffix):
                document = os.path.join(path, i)
                img = cv2.imread(document)
                resultArray.append(img)


    except IOError:
        print ("Error")

    else:
        print ("读取成功")
        return resultArray
#从源路径中读取所有图片放入一个list，然后逐一进行检查，把其中的脸扣下来，存储到目标路径中
def readPicSaveFace(sourcePath,objectPath,*suffix):
    try:
        #读取照片,注意第一个元素是文件名
        resultArray=readAllImg(sourcePath,*suffix)

        #对list中图片逐一进行检查,找出其中的人脸然后写到目标文件夹下

        count = 1
        classfier=cv2.CascadeClassifier("haarcascade_mcs_mouth.xml")
        
        for i in resultArray:
            if type(i) != str:
                grey=cv2.cvtColor(i,cv2.COLOR_BGR2GRAY)
                #人脸检测
                Rects = classfier.detectMultiScale(grey, scaleFactor = 1.2, minNeighbors = 3, minSize = (32, 32))
                if len(Rects) > 0:   
                    for Rect in Rects: 
                        x, y, w, h = Rect 
                        # 打码：使用高斯噪声替换识别出来的人眼所对应的像素值
                        i[y+10:y+h-10,x:x+w,0]=np.random.normal(size=(h-20,w))
                        i[y+10:y+h-10,x:x+w,1]=np.random.normal(size=(h-20,w))
                        i[y+10:y+h-10,x:x+w,2]=np.random.normal(size=(h-20,w))
                        f = cv2.resize(grey[y:(y + h), x:(x + w)], (200, 200))
                        fileName = fileName = str(count)
                        cv2.imwrite(objectPath+os.sep+'%s.jpg' % fileName, i)
                        count += 1


    except IOError:
        print ("Error")

    else:
        print ('Already read '+str(count-1)+' Faces to Destination '+objectPath)
readPicSaveFace("E:/testtt/n000001/",'E:/testttt/','.jpg','.JPG','png','PNG')
# Out:
# 读取成功
# Already read 391 Faces to Destination E:/testttt/

# %%
import numpy as np
import cv2

face_cascade = cv2.CascadeClassifier('D:\Anaconda\envs\py36\Lib\site-packages\cv2\data\haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('haarcascade_mcs_nose.xml')

img = cv2.imread('jj.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

for (x,y,w,h) in faces:
    img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)

cv2.imshow('img',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from skimage import data,exposure,img_as_float
from PIL import Image,ImageFilter
import matplotlib.pyplot as plt

plt.axis('off')
path = "jj.jpg"
figure=Image.open(path)  #读取图片
image=img_as_float(figure)   #转换成指定格式
image=img_as_float(figure)
#figure_adjust_low=exposure.adjust_gamma(image,2)   #图片调暗
figure_adjust_high=exposure.adjust_gamma(image,3)  #图片调亮
#plt.figure()
#plt.subplot(311)
#plt.imshow(figure_adjust_low)


#plt.subplot(312)
plt.imshow(figure_adjust_high)
#plt.subplot(313)
#plt.imshow(figure)
#plt.show()

plt.savefig('E:/1.jpg',bbox_inches='tight',dpi = 300,pad_inches = 0)

# %%
def endwith(s,*endstring):
    resultArray = map(s.endswith,endstring)
    if True in resultArray:
        return True
    else:
        return False

def turnBrightness(imgPath,objectPath,command,*format):
    import os
    from skimage import data,exposure,img_as_float
    from PIL import Image,ImageFilter
    import matplotlib.pyplot as plt
    
    
    s = os.listdir(imgPath)
    print(len(s))
    resultArray = []
    fileName = os.path.basename(imgPath)

    resultArray.append(fileName)
    plt.axis('off')
    
    os.makedirs(objectPath)
    if command == "darker":
        for i in s:
            if endwith(i, format):
                document = os.path.join(imgPath, i)
                #img = cv2.imread(document)
                figure=Image.open(document)
                image=img_as_float(figure)
                figure_adjust_high=exposure.adjust_gamma(image,3)
                plt.imshow(figure_adjust_high)
                #os.path.join("testtt/" + i)
                plt.savefig(objectPath+"/" + i,bbox_inches='tight',dpi = 300,pad_inches = 0)
    elif command == "brighter":
        for i in s:
            if endwith(i, format):
                document = os.path.join(imgPath, i)
                #img = cv2.imread(document)
                figure=Image.open(document)
                image=img_as_float(figure)
                figure_adjust_high=exposure.adjust_gamma(image,0.2)
                #image = Image.open(figure_adjust_high)
                #image = image.convert(1)
                plt.imshow(figure_adjust_high)
                #os.path.join("testtt/" + i)
                #plt.imshow(image)
                plt.savefig(objectPath+"/" + i,bbox_inches='tight',dpi = 300,pad_inches = 0)
    else:
        pass
        
            
turnBrightness("E:/testt/n000078", "E:/testtt/","brighter","jpg")
# Out:
# 351
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# D:\Anaconda\envs\py36\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2769     try:
# -> 2770         fp.seek(0)
#    2771     except (AttributeError, io.UnsupportedOperation):
#
# AttributeError: 'numpy.ndarray' object has no attribute 'seek'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-0d0df296de8d> in <module>
#      51
#      52
# ---> 53 turnBrightness("E:/testt/n000078", "E:/testtt/","brighter","jpg")
#
# <ipython-input-17-0d0df296de8d> in turnBrightness(imgPath, objectPath, command, *format)
#      41                 image=img_as_float(figure)
#      42                 figure_adjust_high=exposure.adjust_gamma(image,0.2)
# ---> 43                 image = Image.open(figure_adjust_high)
# ...

# %%
import cv2
def read_file(path):
    img_list = []
    label_list = []
    dir_counter = 0
    IMG_SIZE = 128

    # read images in all sub_folders and put inro one array
    for child_dir in sorted(os.listdir(path)):
         #print("location a")
         #print(child_dir)
         child_path = os.path.join(path, child_dir)

         for dir_image in  sorted(os.listdir(child_path)): # make sure the sequence does not mess up by sorting
             if endwith(dir_image,'jpg'):
                img = cv2.imread(os.path.join(child_path, dir_image))
                resized_img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
                recolored_img = cv2.cvtColor(resized_img,cv2.COLOR_BGR2GRAY)
                img_list.append(recolored_img)
                label_list.append(dir_counter)
         dir_counter += 1

    img_list = np.array(img_list)

    return img_list,label_list,dir_counter
img_list,label_list,dir_counter = read_file("E:/testt/")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-45657e0f28bd> in <module>
#      24
#      25     return img_list,label_list,dir_counter
# ---> 26 img_list,label_list,dir_counter = read_file("E:/testt/")
#
# <ipython-input-37-45657e0f28bd> in read_file(path)
#      14          for dir_image in  sorted(os.listdir(child_path)): # make sure the sequence does not mess up by sorting
#      15              if endwith(dir_image,'jpg'):
# ---> 16                 img = cv2.imread(os.path.join(child_path, dir_image))
#      17                 resized_img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
#      18                 recolored_img = cv2.cvtColor(resized_img,cv2.COLOR_BGR2GRAY)
#
# KeyboardInterrupt:

# %%
img = cv2.imread("E:/testt/n000001/15738938491.jpg")
resized_img = cv2.resize(img, (128, 128))
recolored_img = cv2.cvtColor(resized_img,cv2.COLOR_BGR2GRAY)
print(np.shape(recolored_img))
# Out:
# (128, 128)

# %%
# get all the images
import os
import cv2
import numpy as np

def endwith(s,*endstring):
    resultArray = map(s.endswith,endstring)
    if True in resultArray:
        return True
    else:
        return False

def readAllImg(path,*format):
    try:

        s = os.listdir(path)
        resultArray = []
        fileName = os.path.basename(path)
        resultArray.append(fileName)

        for i in s:
            if endwith(i, format):
                document = os.path.join(path, i)
                img = cv2.imread(document)
                resultArray.append(img)

    except IOError:
        print ("Error, the file may not be found")

    else:
        #print ("successful")
        return resultArray
#put all the images in one list and crop out the faces

def readPicSaveFace(sourcePath,objectPath,*suffix):
    try:
        #读取照片,注意第一个元素是文件名
        resultArray=readAllImg(sourcePath,*suffix)

        #对list中图片逐一进行检查,找出其中的人脸然后写到目标文件夹下

        count = 1
        classfier=cv2.CascadeClassifier("D:\Anaconda\envs\py36\Lib\site-packages\cv2\data\haarcascade_eye.xml")
        
        for i in resultArray:
            if type(i) != str:
                grey=cv2.cvtColor(i,cv2.COLOR_BGR2GRAY)
                #人脸检测
                Rects = classfier.detectMultiScale(grey, scaleFactor = 1.2, minNeighbors = 3, minSize = (32, 32))
                if len(Rects) > 0:   
                    for Rect in Rects: 
                        x, y, w, h = Rect 
                        # 打码：使用高斯噪声替换识别出来的人眼所对应的像素值
                        i[y+10:y+h-10,x:x+w,0]=np.random.normal(size=(h-20,w))
                        i[y+10:y+h-10,x:x+w,1]=np.random.normal(size=(h-20,w))
                        i[y+10:y+h-10,x:x+w,2]=np.random.normal(size=(h-20,w))
                        f = cv2.resize(grey[y:(y + h), x:(x + w)], (200, 200))
                        fileName = fileName = str(count)
                        cv2.imwrite(objectPath+os.sep+'%s.jpg' % fileName, i)
                        count += 1


    except IOError:
        print ("Error")

    else:
        print ('Already read '+str(count-1)+' Faces to Destination '+objectPath)

if __name__ == '__main__':
  L = []
  path = 'E:/testtt/'
  
  try:
    os.makedirs("E:/testtttt/")
  except:
    pass

  for i in sorted(os.listdir(path)): 
    print(i)
    L.append(i)
    path = os.path.join("E:/testtttt/" + i)
    os.makedirs(path)
  for i in L:
    readPicSaveFace("E:/testtt/"+i,'E:/testtttt/'+i,'.jpg','.JPG','png','PNG')
# Out:
# n000001
# n000009
# n000029
# n000040
# n000078
# n000082
# n000106
# n000129
# n000148
# n000149
# n000178
# n000259
# n000284
# n000363
# n000394
# n000410
# n000452
# n000480
# n000527
# n000596
# n000624
# n000654
# n000658
# n000659
# n000667
# n000689
# n000706
# n000736
# n000740
# n000746
# n000774
# n000775
# n000785
# n000836
# n000838
# n000854
# n000912
# n000928
# n000945
# n000950
# n000958
# n000998
# n001021
# n001059
# n001125
# n001127
# n001146
# n001153
# n001156
# n001174
# n001190
# n001197
# n001199
# n001211
# n001242
# n001256
# n001277
# n001291
# n001293
# n001296
# n001299
# n001302
# n001303
# n001304
# n001337
# n001341
# n001368
# n001401
# n001418
# n001439
# n001446
# n001467
# n001485
# n001576
# n001650
# n001655
# n001672
# n001683
# n001687
# n001708
# n001710
# n001781
# n001811
# n001816
# n001817
# n001830
# n001836
# n001838
# n001850
# n001857
# n001878
# n001898
# n001923
# n001934
# n001935
# n001956
# n001976
# n002009
# n002024
# n002080
# ...

# %%
import os 
from random import shuffle
import shutil 
os.makedirs("E:/test")
L = []
path = "E:/testtttt/"
for i in sorted(os.listdir(path)): 
  L.append(i)
  newPath = os.path.join("E:/test/" + i)
  #os.makedirs(newPath)

for i in L:
  count = 0
  os.makedirs("E:/test/"+i)
  list = sorted(os.listdir("E:/testtttt/" + i))
  shuffle(list)
  for j in list[:20]:
    shutil.copyfile("E:/testtttt/"+i+"/"+j,"E:/test/"+i+"/"+str(count)+".jpg") 
    count += 1

# %%
from keras.utils.vis_utils import plot_model
from keras.models import load_model
model = load_model("D:/桌面/8167.h5")
plot_model(model, to_file='model.png',show_shapes="True")
# Out:
# Using TensorFlow backend.
